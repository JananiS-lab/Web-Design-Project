# %% [markdown]
# <h1>Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#WeatherPy" data-toc-modified-id="WeatherPy-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>WeatherPy</a></span><ul class="toc-item"><li><span><a href="#Generate-Cities-List" data-toc-modified-id="Generate-Cities-List-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Generate Cities List</a></span><ul class="toc-item"><li><span><a href="#Perform-API-Calls" data-toc-modified-id="Perform-API-Calls-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Perform API Calls</a></span></li><li><span><a href="#Convert-Raw-Data-to-DataFrame" data-toc-modified-id="Convert-Raw-Data-to-DataFrame-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Convert Raw Data to DataFrame</a></span></li><li><span><a href="#Plotting-the-Data" data-toc-modified-id="Plotting-the-Data-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Plotting the Data</a></span><ul class="toc-item"><li><span><a href="#Latitude-vs.-Temperature-Plot" data-toc-modified-id="Latitude-vs.-Temperature-Plot-1.1.3.1"><span class="toc-item-num">1.1.3.1&nbsp;&nbsp;</span>Latitude vs. Temperature Plot</a></span></li><li><span><a href="#Noticeable-Trends:" data-toc-modified-id="Noticeable-Trends:-1.1.3.2"><span class="toc-item-num">1.1.3.2&nbsp;&nbsp;</span>Noticeable Trends:</a></span></li><li><span><a href="#Latitude-vs.-Humidity-Plot" data-toc-modified-id="Latitude-vs.-Humidity-Plot-1.1.3.3"><span class="toc-item-num">1.1.3.3&nbsp;&nbsp;</span>Latitude vs. Humidity Plot</a></span></li><li><span><a href="#Noticeable-Trends:" data-toc-modified-id="Noticeable-Trends:-1.1.3.4"><span class="toc-item-num">1.1.3.4&nbsp;&nbsp;</span>Noticeable Trends:</a></span></li><li><span><a href="#Latitude-vs.-Cloudiness-Plot" data-toc-modified-id="Latitude-vs.-Cloudiness-Plot-1.1.3.5"><span class="toc-item-num">1.1.3.5&nbsp;&nbsp;</span>Latitude vs. Cloudiness Plot</a></span></li><li><span><a href="#Noticeable-Trends:" data-toc-modified-id="Noticeable-Trends:-1.1.3.6"><span class="toc-item-num">1.1.3.6&nbsp;&nbsp;</span>Noticeable Trends:</a></span></li><li><span><a href="#Latitude-vs.-Wind-Speed-Plot" data-toc-modified-id="Latitude-vs.-Wind-Speed-Plot-1.1.3.7"><span class="toc-item-num">1.1.3.7&nbsp;&nbsp;</span>Latitude vs. Wind Speed Plot</a></span></li><li><span><a href="#Noticeable-Trends:" data-toc-modified-id="Noticeable-Trends:-1.1.3.8"><span class="toc-item-num">1.1.3.8&nbsp;&nbsp;</span>Noticeable Trends:</a></span></li></ul></li></ul></li><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Linear Regression</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Northern-Hemisphere---Max-Temp-vs.-Latitude-Linear-Regression" data-toc-modified-id="Northern-Hemisphere---Max-Temp-vs.-Latitude-Linear-Regression-1.2.0.1"><span class="toc-item-num">1.2.0.1&nbsp;&nbsp;</span>Northern Hemisphere - Max Temp vs. Latitude Linear Regression</a></span></li><li><span><a href="#Southern-Hemisphere---Max-Temp-vs.-Latitude-Linear-Regression" data-toc-modified-id="Southern-Hemisphere---Max-Temp-vs.-Latitude-Linear-Regression-1.2.0.2"><span class="toc-item-num">1.2.0.2&nbsp;&nbsp;</span>Southern Hemisphere - Max Temp vs. Latitude Linear Regression</a></span></li><li><span><a href="#Northern-Hemisphere---Humidity-(%)-vs.-Latitude-Linear-Regression" data-toc-modified-id="Northern-Hemisphere---Humidity-(%)-vs.-Latitude-Linear-Regression-1.2.0.3"><span class="toc-item-num">1.2.0.3&nbsp;&nbsp;</span>Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression</a></span></li><li><span><a href="#Southern-Hemisphere---Humidity-(%)-vs.-Latitude-Linear-Regression" data-toc-modified-id="Southern-Hemisphere---Humidity-(%)-vs.-Latitude-Linear-Regression-1.2.0.4"><span class="toc-item-num">1.2.0.4&nbsp;&nbsp;</span>Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression</a></span></li><li><span><a href="#Northern-Hemisphere---Cloudiness-(%)-vs.-Latitude-Linear-Regression" data-toc-modified-id="Northern-Hemisphere---Cloudiness-(%)-vs.-Latitude-Linear-Regression-1.2.0.5"><span class="toc-item-num">1.2.0.5&nbsp;&nbsp;</span>Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression</a></span></li><li><span><a href="#Southern-Hemisphere---Cloudiness-(%)-vs.-Latitude-Linear-Regression" data-toc-modified-id="Southern-Hemisphere---Cloudiness-(%)-vs.-Latitude-Linear-Regression-1.2.0.6"><span class="toc-item-num">1.2.0.6&nbsp;&nbsp;</span>Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression</a></span></li><li><span><a href="#Northern-Hemisphere---Wind-Speed-(mph)-vs.-Latitude-Linear-Regression" data-toc-modified-id="Northern-Hemisphere---Wind-Speed-(mph)-vs.-Latitude-Linear-Regression-1.2.0.7"><span class="toc-item-num">1.2.0.7&nbsp;&nbsp;</span>Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression</a></span></li><li><span><a href="#Southern-Hemisphere---Wind-Speed-(mph)-vs.-Latitude-Linear-Regression" data-toc-modified-id="Southern-Hemisphere---Wind-Speed-(mph)-vs.-Latitude-Linear-Regression-1.2.0.8"><span class="toc-item-num">1.2.0.8&nbsp;&nbsp;</span>Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import citipy
import random
import json
from scipy.stats import linregress
from itertools import islice

from pandas.io.json import json_normalize    

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
city_id=[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
   
    #print(city)
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities
# Out:
# ['ushuaia',
#  'coihaique',
#  'hermanus',
#  'tidore',
#  'puerto ayora',
#  'sauce',
#  'cap malheureux',
#  'fortuna',
#  'arraial do cabo',
#  'kabare',
#  'sabha',
#  'chuy',
#  'mataura',
#  'rikitea',
#  'punta arenas',
#  'cape town',
#  'qaanaaq',
#  'ancud',
#  'sisimiut',
#  'copala',
#  'sholapur',
#  'san jose',
#  'kapaa',
#  'illoqqortoormiut',
#  'lavrentiya',
#  'mount isa',
#  'amderma',
#  'hami',
#  'ribeira grande',
#  'samarai',
#  'whitehorse',
#  'saint george',
#  'san cristobal',
#  'lebu',
#  'airai',
#  'saskylakh',
#  'deniliquin',
#  'kodiak',
#  'khatanga',
#  'buta',
#  'new norfolk',
#  'walvis bay',
#  'yellowknife',
#  'chokurdakh',
#  'grindavik',
#  'salalah',
#  'bluff',
#  'albany',
#  'sao joao da barra',
#  'buenos aires',
#  'novikovo',
#  'nikolskoye',
#  'ponta do sol',
#  'jumla',
#  'hithadhoo',
#  'umzimvubu',
#  'honningsvag',
#  'gatesville',
#  'pevek',
#  'inhambane',
#  'dingle',
#  'port alfred',
#  'waitati',
#  'narsaq',
# ...

# %%
#Building the URL

url="https://api.openweathermap.org/data/2.5/weather?"
units ="&units=metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
#Defining lists to store the api call results.
name=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
lat=[]
lon=[]
max_temp=[]
wind=[]


# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
   
    try:
        name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        #print(json.dumps(response, indent=4, sort_keys=True))
    except Exception:
         print("City not found. Skip....")
            
print(f"The City Name is: {name}")
# Out:
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# City not found. Skip....
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#creating and printing a Dataframe
city_df=pd.DataFrame({"City":name,
                      "Cloudiness":cloudiness,
                      "Country":country,
                      "Date":date,
                      "Humidity":humidity,
                      "lat": lat,
                      "lng":lon,
                     "Max Temp":max_temp,
                     "Wind Speed":wind})
city_df
# Out:
#                          City  Cloudiness Country        Date  Humidity  \
# 0                     Ushuaia          75      AR  1590796251        79
# 1                   Coyhaique          90      CL  1590796192        82
# 2                    Hermanus          82      ZA  1590796201        97
# 3                Puerto Ayora          75      EC  1590796408        65
# 4                       Sauce         100      UY  1590796408        87
# ..                        ...         ...     ...         ...       ...
# 548                 Apollonia           9      GR  1590796568        82
# 549                    Xinzhi           8      CN  1590796569        45
# 550                      Atar          51      MR  1590796479        20
# 551  Rio Verde de Mato Grosso           0      BR  1590796569        55
# 552        Acapulco de Juárez          20      MX  1590796448        78
#
#        lat     lng  Max Temp  Wind Speed
# 0   -54.80  -68.30    280.15        4.10
# ...

# %%
#exporting city data into csv
city_df.to_csv('cityweatherdata.csv', index=False)

# %%
#Obtaining the count of records in the Data Frame.
city_df.count()
# Out:
# City          553
# Cloudiness    553
# Country       553
# Date          553
# Humidity      553
# lat           553
# lng           553
# Max Temp      553
# Wind Speed    553
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Noticeable Trends:
# 1) The temperature gradually increases as we appraoach the equator.
#     2) Here we are trying to analyze the max temperature trends.

# %%
#Creating the Latitude vs. Max Temp Scatter Plot
fig, ax = plt.subplots(1, figsize=(6, 4))
plt.scatter(lat, max_temp, marker="o",edgecolors="black")
plt.grid(b=True, which='major', color='#666666', linestyle='-')
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("assets/MaxTemp Map.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Noticeable Trends:
# 1) The humidity gradually increases as we appraoach the equator.
#     2) Here we are trying to analyze the humidity levels across the cities.

# %%
#Creating the Latitude vs. Humidity Sacatter Plot
fig, ax = plt.subplots(1, figsize=(6, 4))
plt.scatter(lat, humidity, marker="o",edgecolors="black")
plt.grid(b=True, which='major', color='#666666', linestyle='-')
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("assets/Humidity Map.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Noticeable Trends:
# 1) The cloudiness graph shows that the day has been cloudy across the cities. The even spred of the scatter plots has lead to this assumption.

# %%
#Creating the Latitude vs. Cloudiness Sacatter Plot
fig, ax = plt.subplots(1, figsize=(6, 4))
plt.scatter(lat, cloudiness, marker="o",edgecolors="black")
plt.grid(b=True, which='major', color='#666666', linestyle='-')
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.savefig("assets/Cloudiness Map.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# #### Noticeable Trends:
# 1) We have had steady winds across all cities on 4/25/20, with very few otuliers ranging at 12mph.

# %%
#Creating the Latitude vs. Wind Speed Sacatter Plot
fig, ax = plt.subplots(1, figsize=(6, 4))
plt.scatter(lat, wind, marker="o",edgecolors="black")
plt.grid(b=True, which='major', color='#666666', linestyle='-')
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("assets/WindSpeed Map.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Creating Northern and Southern Hemisphere DataFrames
NH_df= city_df.loc[(city_df['lat']>0)]
#NH_df
SH_df= city_df.loc[(city_df['lat']<0)]
#SH_df

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Creating Linear Regression for Max Temp vs. Latitude for the Northern Hemisphere.
x_values = NH_df['lat']
y_values = NH_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f'The r-squared is : {rvalue}')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-squared is : -0.7916487912550038

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Creating Linear Regression for Max Temp vs. Latitude for the Southern Hemisphere.
x_values = SH_df['lat']
y_values = SH_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f'The r-squared is : {rvalue}')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-squared is : 0.8132125514599244

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Creating Linear Regression for Humidity vs. Latitude for the Northern Hemisphere.
x_values = NH_df['lat']
y_values = NH_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=20,color="red")
print(f'The r-squared is : {rvalue}')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-squared is : -0.007383534779837159

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Creating Linear Regression for Humidity vs. Latitude for the Southern Hemisphere.
x_values = SH_df['lat']
y_values = SH_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=20,color="red")
print(f'The r-squared is : {rvalue}')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-squared is : 0.04983021132107816

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Creating Linear Regression for Cloudiness vs. Latitude for the Northern Hemisphere.
x_values = SH_df['lat']
x_values = NH_df['lat']
y_values = NH_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=20,color="red")
print(f'The r-squared is : {rvalue}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-squared is : -0.012817271466794827

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Creating Linear Regression for Cloudiness vs. Latitude for the Southern Hemisphere.
x_values = SH_df['lat']
x_values = SH_df['lat']
y_values = SH_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=20,color="red")
print(f'The r-squared is : {rvalue}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-squared is : 0.16969094232170237

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Creating Linear Regression for Wind Speed vs. Latitude for the Northern Hemisphere.
x_values = NH_df['lat']
y_values = NH_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=20,color="red")
#print(f'The r-squared is : {rvalue}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Creating Linear Regression for Wind Speed vs. Latitude for the Northern Hemisphere.
x_values = SH_df['lat']
y_values = SH_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=20,color="red")
print(f'The r-squared is : {rvalue}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
# Out:
# The r-squared is : -0.09462497984106075
